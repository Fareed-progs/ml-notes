# %%
# <center>Assignment 3</center>

# %%
# Name: Fareed Usman

# %%
# AG_no: 2023-ag-7202

# %%
# Degree: BS(Computer sciences)

# %%
# Semester: 5th(E)

# %%
Submited to:

# %% [markdown]
# # Q1: Initialize a list with your first name like
# ## Ali = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
#
# #### ➢ Put even values in array of even numbers
# #### ➢ Put odd values in array of odd numbers
# #### ➢ Put positive values in array of positive numbers
# #### ➢ Put negative values in array of negative numbers
# #### ➢ Print sorted list
# #### ➢ Print list in ascending order
# #### ➢ Print list in descending order
# #### ➢ Print values those are negative
# #### ➢ Print values those are positiv
# #### ➢ Print multiplier of negative number form list
# #### ➢ Print multiplier of positive number form list
# ###  ➢ Take power with last two digit with your AG number and print new list like 6660
# #### take power of each element of array with 60
# #### ➢ Sort and print array in assenting order
# #### ➢ Print array in descending order
# #### ➢ Print numbers which are easily dividable on 5
# #### ➢ Remove most repetitive value from list.

# %% [markdown]
# #### Ali = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
# #### ➢ Extend above list with last four character of AG number like 2020 – AG – 6660
# #### So new list will be Ali = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78, 6660]

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
shani.append(7202)
print(shani)
# Out:
# [100, -23, 33, 25, 150, 90, -71, 33, 45, 33, 54, 63, 69, 74, 78, 7202]

# %% [markdown]
# #### ➢ Insert -4500 at index 5

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
shani.insert(5,-4500)
print(shani)
# Out:
# [100, -23, 33, 25, 150, -4500, 90, -71, 33, 45, 33, 54, 63, 69, 74, 78]

# %% [markdown]
# #### ➢ insert 56777 at end of list

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
shani.append(56777)
print(shani)
# Out:
# [100, -23, 33, 25, 150, 90, -71, 33, 45, 33, 54, 63, 69, 74, 78, 56777]

# %% [markdown]
# #### ➢ maximum value

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
print(max(shani))
# Out:
# 150

# %% [markdown]
# #### ➢ minimum value

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
print(min(shani))
# Out:
# -71

# %% [markdown]
# #### ➢ Put even values in array of even numbers

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
for i in shani:
    if i%2==0:
        print([i],'Even')
# Out:
# [100] Even
# [150] Even
# [90] Even
# [54] Even
# [74] Even
# [78] Even

# %% [markdown]
# #### ➢ Put odd values in array of odd numbers

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
for i in shani:
    if i%2==1:
        print([i],'Odd')
# Out:
# [-23] Odd
# [33] Odd
# [25] Odd
# [-71] Odd
# [33] Odd
# [45] Odd
# [33] Odd
# [63] Odd
# [69] Odd

# %% [markdown]
# #### ➢ Put positive values in array of positive numbers

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
for i in shani:
    if i%2==0:
        print([i],'Postive value')
# Out:
# [100] Postive value
# [150] Postive value
# [90] Postive value
# [54] Postive value
# [74] Postive value
# [78] Postive value

# %% [markdown]
# #### ➢ Put negative values in array of negative numbers

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
for i in shani:
    if i%2==1:
        print([i],'Neagative value')
# Out:
# [-23] Neagative value
# [33] Neagative value
# [25] Neagative value
# [-71] Neagative value
# [33] Neagative value
# [45] Neagative value
# [33] Neagative value
# [63] Neagative value
# [69] Neagative value

# %% [markdown]
# #### ➢ Print sorted list

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
print(sorted(shani))
# Out:
# [-71, -23, 25, 33, 33, 33, 45, 54, 63, 69, 74, 78, 90, 100, 150]

# %% [markdown]
# #### ➢ Print list in ascending order

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
print(shani[::-1])
# Out:
# [78, 74, 69, 63, 54, 33, 45, 33, -71, 90, 150, 25, 33, -23, 100]

# %% [markdown]
# #### ➢ Print list in descending order

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
print(sorted(shani,reverse=True))
# Out:
# [150, 100, 90, 78, 74, 69, 63, 54, 45, 33, 33, 33, 25, -23, -71]

# %% [markdown]
# #### ➢ Print values those are negative

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
for i in shani:
    if i<0:
        print(i)
# Out:
# -23
# -71

# %% [markdown]
# #### ➢ Print values those are positive

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
for i in shani:
    if i>0:
        print(i)
# Out:
# 100
# 33
# 25
# 150
# 90
# 33
# 45
# 33
# 54
# 63
# 69
# 74
# 78

# %% [markdown]
# #### ➢ Print multiplier of negative number form list

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
for i in shani:
    if i<0:
        print(i*i)
# Out:
# 529
# 5041

# %% [markdown]
# #### ➢ Print multiplier of positive number form list

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
for i in shani:
    if i>0:
        print(i*i)
# Out:
# 10000
# 1089
# 625
# 22500
# 8100
# 1089
# 2025
# 1089
# 2916
# 3969
# 4761
# 5476
# 6084

# %% [markdown]
# ###  ➢ Take power with last two digit with your AG number and print new list like 6660
# #### take power of each element of array with 60

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78,7202]
for i in shani:
    print(i**2)
# Out:
# 10000
# 529
# 1089
# 625
# 22500
# 8100
# 5041
# 1089
# 2025
# 1089
# 2916
# 3969
# 4761
# 5476
# 6084
# 51868804

# %% [markdown]
# #### ➢ Sort and print array in assenting order
# .

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78,7202]
print(sorted(shani))
# Out:
# [-71, -23, 25, 33, 33, 33, 45, 54, 63, 69, 74, 78, 90, 100, 150, 7202]

# %% [markdown]
# #### ➢ Print array in descending order

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78,7202]
print(sorted(shani,reverse=True))
# Out:
# [7202, 150, 100, 90, 78, 74, 69, 63, 54, 45, 33, 33, 33, 25, -23, -71]

# %% [markdown]
# #### ➢ Print numbers which are easily dividable on 5

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78,7202]
for i in shani:
    if i/5:
        print(i)
# Out:
# 100
# -23
# 33
# 25
# 150
# 90
# -71
# 33
# 45
# 33
# 54
# 63
# 69
# 74
# 78
# 7202

# %% [markdown]
# #### ➢ Remove most repetitive value from list.

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78,7202]
shani.pop(2)
shani.pop(6)
print(shani)
# Out:
# [100, -23, 25, 150, 90, -71, 45, 33, 54, 63, 69, 74, 78, 7202]

# %% [markdown]
# # Q2: initialize a list which contained 20 types of different fruits and vegetables.

# %%
product_list = ["Apple", "Banana", "Carrot", "Spinach", "Orange",
                "Broccoli", "Grape", "Tomato", "Potato", "Strawberry","Onion", 
                "Pear", "Lettuce", "Cucumber", "Mango","Pepper", "Garlic", "Zucchini", "Kiwi", "Blueberry"]

# %% [markdown]
# #### ➢ Print number of characters of each fruit

# %%
product_list = ["Apple", "Banana", "Carrot", "Spinach", "Orange",
                "Broccoli", "Grape", "Tomato", "Potato", "Strawberry","Onion", 
                "Pear", "Lettuce", "Cucumber", "Mango","Pepper", "Garlic", "Zucchini", "Kiwi", "Blueberry"]
for i in produce_list:
    print(len(i))
# Out:
# 5
# 6
# 6
# 7
# 6
# 8
# 5
# 6
# 6
# 10
# 5
# 4
# 7
# 8
# 5
# 6
# 6
# 8
# 4
# 9

# %% [markdown]
# #### ➢ Print those fruits or vegetables which consisted of 4 characters

# %%
product_list = ["Apple", "Banana", "Carrot", "Spinach", "Orange",
                "Broccoli", "Grape", "Tomato", "Potato", "Strawberry","Onion", 
                "Pear", "Lettuce", "Cucumber", "Mango","Pepper", "Garlic", "Zucchini", "Kiwi", "Blueberry"]
for i in produce_list:
    if len(i)==4:
        print(i)
# Out:
# Pear
# Kiwi

# %% [markdown]
# #### ➢ Print those fruits or vegetables which consisted of greater than 5 characters

# %%
product_list = ["Apple", "Banana", "Carrot", "Spinach", "Orange",
                "Broccoli", "Grape", "Tomato", "Potato", "Strawberry","Onion", 
                "Pear", "Lettuce", "Cucumber", "Mango","Pepper", "Garlic", "Zucchini", "Kiwi", "Blueberry"]
for i in produce_list:
    if len(i)>6:
        print(i)
# Out:
# Spinach
# Broccoli
# Strawberry
# Lettuce
# Cucumber
# Zucchini
# Blueberry

# %% [markdown]
# #### ➢ Print that fruit which contain ‘a’ character

# %%
product_list = ["Apple", "Banana", "Carrot", "Spinach", "Orange",
                "Broccoli", "Grape", "Tomato", "Potato", "Strawberry","Onion", 
                "Pear", "Lettuce", "Cucumber", "Mango","Pepper", "Garlic", "Zucchini", "Kiwi", "Blueberry"]
for i in produce_list:
    if "a" in i:
        print(i)
# Out:
# Banana
# Carrot
# Spinach
# Orange
# Grape
# Tomato
# Potato
# Strawberry
# Pear
# Mango
# Garlic

# %% [markdown]
# #### ➢ Print sorted list

# %%
product_list = ["Apple", "Banana", "Carrot", "Spinach", "Orange",
                "Broccoli", "Grape", "Tomato", "Potato", "Strawberry","Onion", 
                "Pear", "Lettuce", "Cucumber", "Mango","Pepper", "Garlic", "Zucchini", "Kiwi", "Blueberry"]
print(sorted(product_list))
# Out:
# ['Apple', 'Banana', 'Blueberry', 'Broccoli', 'Carrot', 'Cucumber', 'Garlic', 'Grape', 'Kiwi', 'Lettuce', 'Mango', 'Onion', 'Orange', 'Pear', 'Pepper', 'Potato', 'Spinach', 'Strawberry', 'Tomato', 'Zucchini']

# %% [markdown]
# #### ➢ Print that fruit which has even number of character

# %%
product_list = ["Apple", "Banana", "Carrot", "Spinach", "Orange",
                "Broccoli", "Grape", "Tomato", "Potato", "Strawberry","Onion", 
                "Pear", "Lettuce", "Cucumber", "Mango","Pepper", "Garlic", "Zucchini", "Kiwi", "Blueberry"]
for i in product_list:
    if len(i)%2==0:
        print(i)
# Out:
# Banana
# Carrot
# Orange
# Broccoli
# Tomato
# Potato
# Strawberry
# Pear
# Cucumber
# Pepper
# Garlic
# Zucchini
# Kiwi

# %% [markdown]
# # Q3: Manipulate your AG number on following way with use array.

# %% [markdown]
# ####  Insert your ag number charter by character in list 2020-ag-6660

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
shani.insert(16,'2024-ag-7202')
print(shani)
# Out:
# [100, -23, 33, 25, 150, 90, -71, 33, 45, 33, 54, 63, 69, 74, 78, '2024-ag-7202']

# %% [markdown]
# #### ➢ Replace 2020 to 2030

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
shani.insert(16,'2030-ag-7202')
print(shani)
# Out:
# [100, -23, 33, 25, 150, 90, -71, 33, 45, 33, 54, 63, 69, 74, 78, '2030-ag-7202']

# %% [markdown]
# #### ➢ Replace last 4 digits with ****

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
shani.insert(16,'2030-ag-****')
print(shani)
# Out:
# [100, -23, 33, 25, 150, 90, -71, 33, 45, 33, 54, 63, 69, 74, 78, '2030-ag-****']

# %% [markdown]
# #### ➢ Print ag number such a way @2020*-*ag*-*6660@

# %%
shani = [100,-23,33,25,150,90,-71,33,45,33,54,63,69,74,78]
shani.insert(16,'@2030*-*ag*-*7202@')
print(shani)
# Out:
# [100, -23, 33, 25, 150, 90, -71, 33, 45, 33, 54, 63, 69, 74, 78, '@2030*-*ag*-*7202@']
