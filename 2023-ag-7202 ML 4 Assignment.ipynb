# %% [markdown]
# #   <center>Assignment ML 4</center>

# %% [markdown]
# # Name:Fareed Usman

# %% [markdown]
# # AG no: 2023-ag-7202

# %% [markdown]
# # Department:BS(Computer sciences)

# %% [markdown]
# # Semester:5th(e)

# %% [markdown]
# # Submited to: Sir Shoaib Farouq

# %% [markdown]
# # Q1: Apply following function in Dictionary data structure in python for following
# # problem:
# #### items() keys() pop() popitem() values() update()

# %%
Fareed ={'Electronics':{'Laptop':{'Brand1': 'Dell','Brand2':'HP','Brand3':'ASER','Brand4':'TOSHIBA'},
                        'Mobile':{'C1':'NOKIA','C2':'INFNIX','C3':'SAMSUNG','C4':'OPPO'}},
        'Makeup':{'Foundations':{'F1':'MISSROSE','F2':'HUDA BEAUTY','F3':'LOREAL','F4': 'MAC'},
                    'Lipstick':{'L1':'MEDORA','L2':'HUDA BEAUTY','L3':'LOREAL','L4':'FLARMAR'}}}

# %% [markdown]
# ### ➢ Print all mobile and laptop types

# %%
print(Fareed['Electronics'])
# Out:
# {'Laptop': {'Brand1': 'Dell', 'Brand2': 'HP', 'Brand3': 'ASER', 'Brand4': 'TOSHIBA'}, 'Mobile': {'C1': 'NOKIA', 'C2': 'INFNIX', 'C3': 'SAMSUNG', 'C4': 'OPPO'}}

# %% [markdown]
# ### ➢ Print all makeup products

# %%
print(Fareed['Makeup'])
# Out:
# {'Foundations': {'F1': 'MISSROSE', 'F2': 'HUDA BEAUTY', 'F3': 'LOREAL', 'F4': 'MAC'}, 'Lipstick': {'L1': 'MEDORA', 'L2': 'HUDA BEAUTY', 'L3': 'LOREAL', 'L4': 'FLARMAR'}}

# %% [markdown]
# ### ➢ Print only mac from dictionary

# %%
print(Fareed['Makeup']['Foundations']['F4'])
# Out:
# MAC

# %% [markdown]
# ### ➢ Add new laptop mobile and makeup type in
# ### diction in related part.

# %%
Fareed['Electronics']['Laptop'].update({'Brand5':'Thinkpad'})
print(Fareed['Electronics']['Laptop'])
# Out:
# {'Brand1': 'Dell', 'Brand2': 'HP', 'Brand3': 'ASER', 'Brand4': 'TOSHIBA', 'Brand5': 'Thinkpad'}

# %%
Fareed['Electronics']['Mobile'].update({'c5':'Sony xperia'})
print(Fareed['Electronics']['Mobile'])
# Out:
# {'C1': 'NOKIA', 'C2': 'INFNIX', 'C3': 'SAMSUNG', 'C4': 'OPPO', 'c5': 'Sony xperia'}

# %%
print(Fareed['Makeup']['Foundations'].update({'F5':'Rivaj'}))
print(Fareed['Makeup']['Foundations'])
# Out:
# None
# {'F1': 'MISSROSE', 'F2': 'HUDA BEAUTY', 'F3': 'LOREAL', 'F4': 'MAC', 'F5': 'Rivaj'}

# %%
print(Fareed['Makeup']['Lipstick'].update({'L5':'Derma'}))
print(Fareed['Makeup']['Lipstick'])
# Out:
# None
# {'L1': 'MEDORA', 'L2': 'HUDA BEAUTY', 'L3': 'LOREAL', 'L4': 'FLARMAR', 'L5': 'Derma'}

# %% [markdown]
# ### ➢ Remove MEDORA from dictionary.

# %%
print(Fareed['Makeup']['Lipstick'].pop('L1'))
# Out:
# MEDORA

# %%
print(Fareed['Makeup']['Lipstick'])
# Out:
# {'L2': 'HUDA BEAUTY', 'L3': 'LOREAL', 'L4': 'FLARMAR', 'L5': 'Derma'}

# %% [markdown]
# ### ➢ Print only Brand3, C4, F4, L2

# %%
print(Fareed['Electronics']['Mobile']['C4'])
# Out:
# OPPO

# %%
print(Fareed['Makeup']['Foundations']['F4'])
# Out:
# MAC

# %%
print(Fareed['Makeup']['Lipstick']['L2'])
# Out:
# HUDA BEAUTY

# %% [markdown]
# ### ➢ Add new complete category and sub category of
# ### your desire product in dictionary

# %%
Fareed.update({'Auto_Mobile':{'Cars':{'c1':'BMW_e46','c2':'BMW_M5'}}})

# %%
print(Fareed['Auto_Mobile']['Cars'])
# Out:
# {'c1': 'BMW_e46', 'c2': 'BMW_M5'}

# %% [markdown]
# ### ➢ Remove any laptop, mobile, foundation and
# ### lipstick from dictionary.

# %%
print(Fareed['Makeup']['Lipstick'].pop('L2'))
# Out:
# HUDA BEAUTY

# %%
print(Fareed['Makeup']['Lipstick'])
# Out:
# {'L3': 'LOREAL', 'L4': 'FLARMAR', 'L5': 'Derma'}

# %%
print(Fareed['Makeup']['Foundations'].pop('F1'))
# Out:
# MISSROSE

# %%
print(Fareed['Makeup']['Lipstick'])
# Out:
# {'L3': 'LOREAL', 'L4': 'FLARMAR', 'L5': 'Derma'}

# %%
print(Fareed['Electronics']['Laptop'].pop('Brand4'))
# Out:
# TOSHIBA

# %%
print(Fareed['Electronics']['Laptop'])
# Out:
# {'Brand1': 'Dell', 'Brand2': 'HP', 'Brand3': 'ASER', 'Brand5': 'Thinkpad'}

# %%
print(Fareed['Electronics']['Mobile'].pop('C1'))
# Out:
# NOKIA

# %%
print(Fareed['Electronics']['Mobile'])
# Out:
# {'C2': 'INFNIX', 'C3': 'SAMSUNG', 'C4': 'OPPO', 'c5': 'Sony xperia'}

# %% [markdown]
# ### Using for loops
# #### • Print those products which start from ‘M’

# %%
for a,b in Fareed.items():  
    for c,d in b.items():
        for e,f in d.items():
            if 'M' in f:
                print(f)
# Out:
# SAMSUNG
# MISSROSE
# MAC
# FLARMAR
# BMW_e46
# BMW_M5

# %% [markdown]
# #### • Print those products which contained ‘M’ and
# #### ‘E’

# %%
for a,b in Fareed.items():  
    for c,d in b.items():
        for e,f in d.items():
            if 'M' in f and 'E' in f:
                print(f)
# Out:
# MISSROSE

# %% [markdown]
# #### • Print those products which contained
# #### number of characters less than 4

# %%
for a,b in Fareed.items():  
    for c,d in b.items():
        for e,f in d.items():
            if  len(f) <4:
                    print(f)
# Out:
# HP
# MAC

# %% [markdown]
# #### • Print product with number of characters

# %%
for a,b in Fareed.items():  
    for c,d in b.items():
        for e,f in d.items():
            print(len(f),f)
# Out:
# 4 Dell
# 2 HP
# 4 ASER
# 7 TOSHIBA
# 8 Thinkpad
# 6 INFNIX
# 7 SAMSUNG
# 4 OPPO
# 11 Sony xperia
# 8 MISSROSE
# 11 HUDA BEAUTY
# 6 LOREAL
# 3 MAC
# 5 Rivaj
# 11 HUDA BEAUTY
# 6 LOREAL
# 7 FLARMAR
# 5 Derma
# 7 BMW_e46
# 6 BMW_M5

# %% [markdown]
# #### • Print those Mobile names which contained ‘I’

# %%
for a,b in Fareed.items():  
    for c,d in b.items():
        for e,f in d.items():
            if 'I' in f:
                print(f)
# Out:
# TOSHIBA
# INFNIX
# MISSROSE

# %% [markdown]
# #### • Print those foundations names which
# #### contained ‘Y’ at the last position

# %%
for a,b in Fareed.items():  
    for c,d in b.items():
        for e,f in d.items():
            
            if f[-1]=='Y':
                print(f)
# Out:
# HUDA BEAUTY
# HUDA BEAUTY
